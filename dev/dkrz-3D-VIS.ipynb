# %%
import vis_eulag
import importlib

# %%
# --- traslb3D_000 ------ #
import vis_eulag
importlib.reload(vis_eulag)
from vis_eulag import *
SETTINGS = load_settings('settings_translb3D.txt')
SETTINGS['FILE_LOCATION'] = "/scratch/b/b309199/translb_lid_pnj"
SETTINGS['FILE_LOCATION'] = "/scratch/b/b309199/osclb"
#SETTINGS['FILE_LOCATION'] = "/work/bd0620/b309199/translb_lid_pnj"
vis_eulag(SETTINGS)
# Out:
# Using tapes.nc...
# Using grd.nc attributes...
# Defining constants...
# Defining pref00...Done
# Plot folder already exists and will be overwritten...
# Visualize yz plots in t-x frame for single variable...Done
# Visualize xy plots in t-z frame for single variable...Done
# Visualize x-z planes...Done
# Visualize x-y planes...Done
# Visualize Lidar profiles...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /sw/spack-levante/mambaforge-23.1.0-1-Linux-x86_64-3boc6i/lib/python3.10/site-packages/xarray/core/dataset.py:1353, in Dataset._construct_dataarray(self, name)
#    1352 try:
# -> 1353     variable = self._variables[name]
#    1354 except KeyError:
#
# KeyError: 'u'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 9
# ...

# %%
### Visualize the slice thing

# %%
import vis_eulag
importlib.reload(vis_eulag)
from vis_eulag import *
SETTINGS = load_settings('settings_translb3D.txt')
# --- traslb3D_002 ------ #
SETTINGS['FILE_LOCATION'] = "/scratch/b/b309199/translbq3D_002_lid_256"
#vis_eulag(SETTINGS)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 import vis_eulag
# ----> 2 importlib.reload(vis_eulag)
#       3 from vis_eulag import *
#       4 SETTINGS = load_settings('settings_translb3D.txt')
#
# NameError: name 'importlib' is not defined

# %%
import vis_eulag
importlib.reload(vis_eulag)
from vis_eulag import *
SETTINGS = load_settings('settings_translb3D.txt')
SETTINGS['FILE_LOCATION'] = "/scratch/b/b309199/iso_mtn_2D"
vis_eulag(SETTINGS)
# Out:
# Using tapes.nc...
# Using grd.nc attributes...
# Defining constants...
# Defining pref00...Done
# Plot folder already exists and will be overwritten...
# Visualize yz plots in t-x frame for single variable...Done
# Visualize xy plots in t-z frame for single variable...Done
# Visualize x-z planes...Done
# Visualize vertical profiles...Done
# --- 6.096117258071899 seconds ---
